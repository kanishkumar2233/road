# %%
from IPython.core.display import HTML

print("Welcome to your simple quiz chatbot!")
print("Answer the questions by typing a, b, c, or d\n")

score = 0

questions = [
    {
        "question": "1. Who is known as the father of computers?",
        "a": "Charles Babbage",
        "b": "Alan Turing",
        "c": "Bill Gates",
        "d": "Tim Berners-Lee",
        "answer": "a"
    },
    {
        "question": "2. What is the chemical symbol for water?",
        "a": "H2O",
        "b": "O2",
        "c": "CO2",
        "d": "NaCl",
        "answer": "a"
    },
    {
        "question": "3. Which planet is known as the Red Planet?",
        "a": "Earth",
        "b": "Mars",
        "c": "Jupiter",
        "d": "Venus",
        "answer": "b"
    },
    {
        "question": "4. Who wrote the Ramayana?",
        "a": "Valmiki",
        "b": "Tulsidas",
        "c": "Vyasa",
        "d": "Kalidasa",
        "answer": "a"
    },
    {
        "question": "5. What gas do plants release during photosynthesis?",
        "a": "Oxygen",
        "b": "Carbon dioxide",
        "c": "Nitrogen",
        "d": "Helium",
        "answer": "a"
    },
    {
        "question": "6. Which device is used to measure temperature?",
        "a": "Barometer",
        "b": "Thermometer",
        "c": "Hygrometer",
        "d": "Anemometer",
        "answer": "b"
    },
    {
        "question": "7. Who invented the telephone?",
        "a": "Thomas Edison",
        "b": "Alexander Graham Bell",
        "c": "Nikola Tesla",
        "d": "James Watt",
        "answer": "b"
    },
    {
        "question": "8. Which animal is known as the Ship of the Desert?",
        "a": "Camel",
        "b": "Horse",
        "c": "Donkey",
        "d": "Yak",
        "answer": "a"
    },
    {
        "question": "9. What is the largest ocean on Earth?",
        "a": "Atlantic Ocean",
        "b": "Indian Ocean",
        "c": "Pacific Ocean",
        "d": "Arctic Ocean",
        "answer": "c"
    },
    {
        "question": "10. Which organ pumps blood in the human body?",
        "a": "Lungs",
        "b": "Brain",
        "c": "Heart",
        "d": "Kidney",
        "answer": "c"
    }
]

for q in questions:
    print(q["question"])
    print("a)", q["a"])
    print("b)", q["b"])
    print("c)", q["c"])
    print("d)", q["d"])

    user_ans = input("Your answer: ").lower()

    if user_ans == q["answer"]:
        print("Correct!\n")
        score += 1
    else:
        print(f"Wrong! Correct answer is: {q['answer']}\n")

print("Your Final Score:", score, "/", len(questions))
# Out:
# Welcome to your simple quiz chatbot!
# Answer the questions by typing a, b, c, or d
#
# 1. Who is known as the father of computers?
# a) Charles Babbage
# b) Alan Turing
# c) Bill Gates
# d) Tim Berners-Lee
# Your answer: a
# Correct!
#
# 2. What is the chemical symbol for water?
# a) H2O
# b) O2
# c) CO2
# d) NaCl
# Your answer: a
# Correct!
#
# 3. Which planet is known as the Red Planet?
# a) Earth
# b) Mars
# c) Jupiter
# d) Venus
